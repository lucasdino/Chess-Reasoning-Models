# %%
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv("chess_action_value_test.csv")

print(df.info())

# Display the first few rows
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62561 entries, 0 to 62560
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FEN              62561 non-null  object
#  1   Move             62561 non-null  object
#  2   Win Probability  62561 non-null  object
# dtypes: object(3)
# memory usage: 1.4+ MB
# None
#                                                  FEN  \
# 0  1B2n1k1/3b2p1/1b2pp1p/1p6/p3N3/P4P2/1P4PP/3B3K...
# 1  1B2n1k1/4bp2/3p2pp/2p1p3/2P1P2P/p1rP2P1/8/N4BK...
# 2  1B2n1k1/4bp2/3p2pp/2p1p3/p1P1P2P/2rP2P1/2N5/5B...
# 3  1B2n1k1/4bp2/3p2pp/2p1p3/p1P1P2P/2rP2P1/8/N4BK...
# 4  1B2n1k1/4bp2/3p2pp/2p1p3/p1P1P2P/r2P2P1/2N5/5B...
# 5  1B2n1k1/4bp2/3p2pp/2p1p3/p1P1P2P/r2P2P1/8/4NBK...
# 6  1B2n1k1/5p2/3p1bpp/2p1p3/p1P1P2P/r2P1NP1/8/5BK...
# 7  1B2n1k1/5p2/3p1bpp/2p1p3/p1P1P2P/r2P2P1/8/4NBK...
# 8  1B2n1k1/5pb1/3p2pp/2p1p1N1/p1P1P2P/r2P2P1/8/5B...
# ...
